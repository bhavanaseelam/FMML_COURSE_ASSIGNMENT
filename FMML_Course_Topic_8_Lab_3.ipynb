# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavanaseelam/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-25 12:13:32--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   209MB/s    in 0.3s
#
# 2023-05-25 12:13:33 (209 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29755  1710.04778v1  As a non-invasive imaging modality, optical co...    cs
# 16004  1608.01965v1  The identification of authorship in disputed d...    cs
# 32891  1510.06002v2  We present an efficient method for training sl...    cs
# 22057   1407.7840v1  Matrix factorization (MF) has become a common ...  stat
# 36093   1406.3506v1  Hotspot detection aims at identifying subgroup...    cs
# ...             ...                                                ...   ...
# 37842   0807.3719v2  This paper focuses on obtaining clustering inf...  stat
# 9256   1711.03736v1  Recently by the development of the Internet an...    cs
# 3460   1706.03825v1  Explaining the output of a deep network remain...    cs
# 14299  1707.09971v2  This paper is concerned with the problem of to...  stat
# 40596   0910.5260v2  We consider the problem of reconstructing a lo...    cs
#
#                                                    title  year  \
# 29755  Retinal Fluid Segmentation and Detection in Op...  2017
# 16004  Text authorship identified using the dynamics ...  2016
# 32891  Fast and Scalable Structural SVM with Slack Re...  2015
# 22057  Bayesian Probabilistic Matrix Factorization: A...  2014
# 36093  Eigenspace Method for Spatiotemporal Hotspot D...  2014
# ...                                                  ...   ...
# 37842  Data spectroscopy: Eigenspaces of convolution ...  2008
# 9256   Joint Sentiment/Topic Modeling on Text Data Us...  2017
# 3460          SmoothGrad: removing noise by adding noise  2017
# 14299  Spectral Method and Regularized MLE Are Both O...  2017
# 40596  A Gradient Descent Algorithm on the Grassman M...  2009
#
#                                                 keywords
# 29755  [coherence, tomography, micrometer, resolution...
# 16004  [identification, authorship, documents, expert...
# 32891  [efficient, structural, violating, formulation...
# 22057  [factorization, collaborative, filtering, impl...
# 36093  [detection, identifying, subgroups, observatio...
# ...                                                  ...
# 37842  [obtaining, clustering, information, distribut...
# 9256   [development, different, processing, practical...
# 3460   [explaining, challenge, classifier, explanatio...
# 14299  [concerned, comparisons, collection, compariso...
# 40596  [reconstructing, implementation, efficient, al...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29755    [coherence, tomography, micrometer, resolution...
# 16004    [identification, authorship, documents, expert...
# 32891    [efficient, structural, violating, formulation...
# 22057    [factorization, collaborative, filtering, impl...
# 36093    [detection, identifying, subgroups, observatio...
#                                ...
# 24710    [automated, detection, screening, retinopathy,...
# 39509    [addresses, navigation, implement, contributio...
# 27492    [structure, accelerating, inference, convoluti...
# 9441     [biostatistics, propensity, imbalance, covaria...
# 11652    [clustering, frequently, clustering, community...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8821 words.
# Out of those 4504 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="ab7045f2-7143-47a0-a90e-55ba52658b37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ab7045f2-7143-47a0-a90e-55ba52658b37")) {                    Plotly.newPlot(                        "ab7045f2-7143-47a0-a90e-55ba52658b37",                        [{"x":["segmented","experiments","validation","recognize","micrometer","diagnosis","resolution","segmentation","framework","performed","structures","associated","convolutional","algorithm","coherence","therefore","detection","classification","tomography","characteristics","authorship","distribution","expertise","unfeasible","identified","introduced","procedure","methodology","description","classified","occurrence","comparison","identification","applications","optimized","characterize","introduce","supervised","correctly","fluctuations","topological","linguistic","remarkable","representing","stationary","practical","documents","attributes","violating","efficient","approaches","structure","difficult","formulation","rescaling","contribution","decomposes","structural","magnitude","constrained","extensions","variational","experimental","literature","filtering","distributed","frequency","scalability","probabilistic","treatment","drawbacks","implementation","algorithms","factorization","information","heteroskedastic","deterministic","approximation","outperforms","collaborative","truncated","overfitting","precision","incorporate","estimation","evaluation","assumption","identifying","exhaustively","restrictive","observations","eigenspace","significant","approximated","spatiotemporal","comprehensive","correlation","subgroups","effectiveness","unexpected","combination","unrealistic","surveillance","statistics","principal","simulated","exhaustive","computational","efficiency","population","assumptions","numerical","regression","illustrate","applicability","relatively","classifier","frequently","randomized","unsupervisedly","unsupervised","knowledge","cognitive","representations","variances","extraction","googlenet","distances","existence","afterwards","semantics","operations","arithmetic","resultant","architecture","regardless","embedding","meaningful","encountered","correlated","surprisingly","separates","clustered","community","parameter","particular","parametric","distributions","modelling","nonparametric","hierarchical","probability","designing","processes","stochastic","dirichlet","analytics","extension","demonstrate","attitudes","establish","advertising","mainstream","preserving","superiority","fundamental","investigate","prediction","baselines","autoencoders","unobserved","recommendation","sentiment","heterogeneous","predicting","dimension","monitoring","analytically","efficiently","detecting","environmental","symmetric","organizing","comparative","transportation","exceptions","adaptation","available","infrastructure","furthermore","traditional","reconnaissance","maneuvering","importance","activation","challenge","maximized","deployment","asymmetric","conflicts"],"y":[27,593,50,44,2,55,132,204,549,130,150,102,382,836,16,139,367,486,26,81,9,198,10,1,31,131,128,72,64,32,32,159,106,416,51,49,313,175,36,3,18,83,19,83,25,149,79,55,1,409,431,361,154,85,1,83,8,76,56,51,37,57,412,111,49,105,61,37,152,32,10,119,585,41,719,1,43,122,268,21,7,21,70,64,217,268,59,77,6,5,75,4,245,20,13,53,67,2,217,6,140,2,28,56,40,69,16,287,179,46,52,86,125,79,53,65,158,33,21,2,159,355,52,229,4,146,7,34,28,10,108,70,9,9,237,10,104,44,9,41,34,10,17,84,107,271,36,106,50,21,103,163,53,110,134,16,17,88,569,3,52,9,6,51,34,87,139,231,58,25,6,30,45,40,86,63,31,7,156,78,23,25,21,34,13,3,65,301,12,183,187,2,1,91,30,150,5,16,13,11],"type":"bar"},{"x":["segmented","experiments","validation","recognize","micrometer","diagnosis","resoluti ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4504,), (4504, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Counting</span> <span style=''>Belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Propagation</span> <br/><br/><span style=''>A</span> <span style=''>major</span> <span style=''>benefit</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3815789473684211);'>graphical</span> <span style=''>models</span> <span style=''>is</span> <span style=''>that</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.39215686274509803);'>knowledge</span> <span style=''>is</span> <span style=''>captured</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>Many</span> <span style=''>models</span> <span style=''>however</span> <span style=''>produce</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>problems</span> <span style=''>with</span> <span style=''>a</span> <span style=''>lot</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetries</span> <span style=''>not</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>reflected</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3815789473684211);'>graphical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>hence</span> <span style=''>not</span> <span style=''>exploitable</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>such</span> <span style=''>as</span> <span style=''>belief</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propagation</span> <span style=''>(BP)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>and</span> <span style=''>simple</span> <span style=''>BP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style=''>counting</span> <span style=''>BP</span> <span style=''>that</span> <span style=''>exploits</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>additional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetries</span> <span style=''>Starting</span> <span style=''>from</span> <span style=''>a</span> <span style=''>given</span> <span style=''>factor</span> <span style=''>graph</span> <span style=''>counting</span> <span style=''>BP</span> <span style=''>first</span> <span style='background-color:rgba(0, 255, 0, 0.3939393939393939);'>constructs</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>compressed</span> <span style=''>factor</span> <span style=''>graph</span> <span style=''>of</span> <span style=''>clusternodes</span> <span style=''>and</span> <span style=''>clusterfactors</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>sets</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>factors</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714285);'>indistinguishable</span> <span style=''>given</span> <span style=''>the</span> <span style=''>evidence</span> <span style=''>Then</span> <span style=''>it</span> <span style=''>runs</span> <span style=''>a</span> <span style=''>modified</span> <span style=''>BP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>on</span> <span style=''>the</span> <span style='background- ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Proximal</span> <span style=''>gradient</span> <span style=''>method</span> <span style=''>for</span> <span style=''>huberized</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machine</span> <br/><br/><span style=''>The</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machine</span> <span style=''>(SVM)</span> <span style=''>has</span> <span style=''>been</span> <span style=''>used</span> <span style=''>in</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>The</span> <span style=''>original</span> <span style=''>SVM</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>which</span> <span style=''>is</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style=''>and</span> <span style=''>makes</span> <span style=''>the</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>SVMs</span> <span style=''>such</span> <span style=''>as</span> <span style=''>with</span> <span style=''>ell</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considers</span> <span style=''>the</span> <span style=''>Huberized</span> <span style=''>SVM</span> <span style=''>(HSVM)</span> <span style=''>which</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differentiable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>hinge</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>We</span> <span style=''>first</span> <span style=''>explore</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Proximal</span> <span style=''>Gradient</span> <span style=''>(PG)</span> <span style=''>method</span> <span style=''>to</span> <span style=''>solving</span> <span style=''>binary</span> <span style=''>class</span> <span style=''>HSVM</span> <span style=''>(B</span> <span style=''>HSVM)</span> <span style=''>and</span> <span style=''>then</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalize</span> <span style=''>it</span> <span style=''>to</span> <span style=''>multi</span> <span style=''>class</span> <span style=''>HSVM</span> <span style=''>(M</span> <span style=''>HSVM)</span> <span style=''>Under</span> <span style=''>strong</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>assumptions</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>linearly</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>give</span> <span style=''>a</span> <span style=''>finite</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>result</span> <span style=''>about</span> <span style=''>the</span> <span style=''>support</span> <span style=''>of</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>Differentially</span> <span style=''>Private</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>Revisited</span> <span style=''>Faster</span> <span style=''>and</span> <span style=''>More</span> <span style=''>General</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.47368421052631576);'>differentially</span> <span style=''>private</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Empirical</span> <span style=''>Risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style=''>(ERM)</span> <span style=''>problem</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3267326732673267);'>different</span> <span style=''>settings</span> <span style=''>For</span> <span style=''>smooth</span> <span style=''>(strongly)</span> <span style=''>convex</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>with</span> <span style=''>or</span> <span style=''>without</span> <span style=''>(non)</span> <span style=''>smooth</span> <span style='background-color:rgba(255, 0, 0, 0.38461538461538464);'>regularization</span> <span style=''>we</span> <span style=''>give</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>either</span> <span style=''>optimal</span> <span style=''>or</span> <span style=''>near</span> <span style=''>optimal</span> <span style=''>utility</span> <span style=''>bounds</span> <span style=''>with</span> <span style=''>less</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>compared</span> <span style=''>with</span> <span style=''>previous</span> <span style=''>work</span> <span style=''>For</span> <span style=''>ERM</span> <span style=''>with</span> <span style=''>smooth</span> <span style=''>convex</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3356890459363957);'>dimensional</span> <span style=''>(pgg</span> <span style=''>n)</span> <span style=''>setting</span> <span style=''>we</span> <span style=''>give</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>which</span> <span style=''>achieves</span> <span style=''>the</span> <span style=''>upper</span> <span style=''>bound</span> <span style=''>with</span> <span style=''>less</span> <span style=''>gradient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>than</span> <span style=''>previous</span> <span style=''>ones</span> <span style=''>At</span> <span style=''>last</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalize</span> <span style=''>the</span> <span style=''>expected</span> <span style=''>excess</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style=''>from</span> <span style=''>convex</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>to</span> <span style=''>non</span> <span style=''>convex</span> <span style=''>ones</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>satisfying</span> <span style=''>the</span> <span style=''>Polyak</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>Lojasiewicz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditio ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fractional</span> <span style=''>set</span> <span style=''>programs</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>in</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <br/><br/><span style=''>The</span> <span style=''>(constrained)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>ratio</span> <span style=''>of</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>is</span> <span style=''>a</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>frequently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurring</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>community</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>As</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>typically</span> <span style=''>NP</span> <span style=''>hard</span> <span style=''>one</span> <span style=''>uses</span> <span style=''>convex</span> <span style=''>or</span> <span style=''>spectral</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>While</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxations</span> <span style=''>can</span> <span style=''>be</span> <span style=''>solved</span> <span style=''>globally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimally</span> <span style=''>they</span> <span style=''>are</span> <span style=''>often</span> <span style=''>too</span> <span style=''>loose</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>results</span> <span style=''>far</span> <span style=''>away</span> <span style=''>from</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>every</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>a</span> <span style=''>ratio</span> <span style=''>of</span> <span style=''>non</span> <span style=''>negative</span> <span style=''>set</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functions</span> <span style=''>allows</span> <span style=''>a</span> <span style=''>tight</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relaxation</span> <span style=''>into</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unconstrained</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>This</span> <span style=''>result</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>flexible</span> <span style='background-color:rgba(255,  ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08464285714285714)
# 	knowledge (0.12678571428571428)
# 	processing (0.10642857142857143)
# 	segmentation (0.07285714285714286)
# 	experimental (0.14714285714285713)
# 	information (0.2567857142857143)
# 	different (0.26321428571428573)
# 	detection (0.13107142857142856)
# 	recognition (0.12928571428571428)
# 	convolutional (0.13642857142857143)
#
# Some Statistics words are:
# 	algorithm (0.376)
# 	distributions (0.12)
# 	estimation (0.165)
# 	theoretical (0.1495)
# 	statistical (0.15)
# 	variables (0.14)
# 	distribution (0.184)
# 	inference (0.195)
# 	dimensional (0.189)
# 	regression (0.1855)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="a12a7eaa-82ad-4bc3-a66c-9b211ccdca29" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a12a7eaa-82ad-4bc3-a66c-9b211ccdca29")) {                    Plotly.newPlot(                        "a12a7eaa-82ad-4bc3-a66c-9b211ccdca29",                        [{"x":["segmented","experiments","validation","recognize","micrometer","diagnosis","resolution","segmentation","framework","performed","structures","associated","convolutional","algorithm","coherence","therefore","detection","classification","tomography","characteristics","authorship","distribution","expertise","unfeasible","identified","introduced","procedure","methodology","description","classified","occurrence","comparison","identification","applications","optimized","characterize","introduce","supervised","correctly","fluctuations","topological","linguistic","remarkable","representing","stationary","practical","documents","attributes","violating","efficient","approaches","structure","difficult","formulation","rescaling","contribution","decomposes","structural","magnitude","constrained","extensions","variational","experimental","literature","filtering","distributed","frequency","scalability","probabilistic","treatment","drawbacks","implementation","algorithms","factorization","information","heteroskedastic","deterministic","approximation","outperforms","collaborative","truncated","overfitting","precision","incorporate","estimation","evaluation","assumption","identifying","exhaustively","restrictive","observations","eigenspace","significant","approximated","spatiotemporal","comprehensive","correlation","subgroups","effectiveness","unexpected","combination","unrealistic","surveillance","statistics","principal","simulated","exhaustive","computational","efficiency","population","assumptions","numerical","regression","illustrate","applicability","relatively","classifier","frequently","randomized","unsupervisedly","unsupervised","knowledge","cognitive","representations","variances","extraction","googlenet","distances","existence","afterwards","semantics","operations","arithmetic","resultant","architecture","regardless","embedding","meaningful","encountered","correlated","surprisingly","separates","clustered","community","parameter","particular","parametric","distributions","modelling","nonparametric","hierarchical","probability","designing","processes","stochastic","dirichlet","analytics","extension","demonstrate","attitudes","establish","advertising","mainstream","preserving","superiority","fundamental","investigate","prediction","baselines","autoencoders","unobserved","recommendation","sentiment","heterogeneous","predicting","dimension","monitoring","analytically","efficiently","detecting","environmental","symmetric","organizing","comparative","transportation","exceptions","adaptation","available","infrastructure","furthermore","traditional","reconnaissance","maneuvering","importance","activation","challenge","maximized","deployment","asymmetric","conflicts","operators","comprised","evaluated","optimization","performance","generates","strategies","increasing","individual","different","producing","potential","motivated","evolutionary","predetermined","environments","deploying","biological","possibilities","threshold","mechanism","multiagent","otherwise","scientists","artificial","collectively","processing","consistent","engineers","dependent","engineering","technique","important","guarantees","guarantee","significantly","typically","dimensionality","representation","dimensional","compressed","preserves","achieving","dimensions","approximate","reconstruction","application","isometric","embeddings","reduction","experimentally","theoretical","including","leverages","preprocessing","geometric","a ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	correspondingly
# 	reparametrization
# 	propensity
# 	aerodynamic
# 	depression
# 	linearnonlinear
# 	complemented
# 	connectome
# 	precisions
# 	definiteness
# 	recombines
# 	ingenious
# 	neuroscientists
# 	factorial
# 	measurability
# 	magnetoencephalographic
# 	psychiatric
# 	davenport
# 	bernsteins
# 	repeatmulti
# Some words which never appear in Statistics papers:
# 	micrometer
# 	unsupervisedly
# 	reconnaissance
# 	multiagent
# 	consciousness
# 	conscious
# 	electrically
# 	occlusions
# 	appearances
# 	judgements
# 	discourse
# 	affective
# 	communicative
# 	subjectivity
# 	succession
# 	watershed
# 	pedestrian
# 	occurence
# 	continued
# 	steepness

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.076544425301501e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7783333333333333
